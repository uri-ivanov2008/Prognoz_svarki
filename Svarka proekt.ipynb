# %% [markdown]
# # Итоговый проект Иванова Юрия Викторовича

# %% [markdown]
# ### <a href = "https://github.com/uri-ivanov2008/Prognoz_svarki">Ссылка на github</a>

# %% [markdown]
# # Импорты

# %%
# !pip install phik --quiet
# !pip install numpy
# !pip install warnings
# !pip install seaborn
# !pip install tensorflow
# !pip install matplotlib
# !pip install phik
# !pip install -U scikit-learn scipy matplotlib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import warnings
warnings.filterwarnings("ignore")
import pickle
from matplotlib import rcParams
import phik
from phik import resources, report 
from phik.report import plot_correlation_matrix 
import sklearn 
from sklearn.preprocessing import MinMaxScaler, StandardScaler, Normalizer 
from sklearn import metrics 
from sklearn.multioutput import MultiOutputRegressor
from sklearn import tree
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score 
from sklearn.model_selection import train_test_split, cross_val_score, cross_validate, KFold 
from sklearn.dummy import DummyRegressor 
from sklearn.linear_model import LinearRegression, SGDRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor 
from sklearn.tree import DecisionTreeRegressor 
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPRegressor 
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV 
from scipy import stats 
from sklearn.svm import SVR 
from tensorflow import keras
# Out:
# Requirement already satisfied: numpy in c:\users\lenurchik\anaconda3\lib\site-packages (1.26.4)
# ERROR: Could not find a version that satisfies the requirement warnings (from versions: none)
# ERROR: No matching distribution found for warnings
# Requirement already satisfied: seaborn in c:\users\lenurchik\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\lenurchik\anaconda3\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\lenurchik\anaconda3\lib\site-packages (from seaborn) (2.1.4)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\lenurchik\anaconda3\lib\site-packages (from seaborn) (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lenurchik\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\lenurchik\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lenurchik\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\lenurchik\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\lenurchik\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.0)
# Requirement already satisfied: pillow>=8 in c:\users\lenurchik\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\lenurchik\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lenurchik\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lenurchik\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\lenurchik\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\lenurchik\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Requirement already satisfied: tensorflow in c:\users\lenurchik\anaconda3\lib\site-packages (2.16.1)
# Requirement already satisfied: tensorflow-intel==2.16.1 in c:\users\lenurchik\anaconda3\lib\site-packages (from tensorflow) (2.16.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\lenurchik\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\lenurchik\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\lenurchik\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\lenurchik\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\lenurchik\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\lenurchik\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\lenurchik\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in c:\users\lenurchik\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\lenurchik\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\lenurchik\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (24.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\lenurchik\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\lenurchik\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.31.0)
# Requirement already satisfied: setuptools in c:\users\lenurchik\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (68.2.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\lenurchik\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\lenurchik\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\lenurchik\appdata\roaming\python\python311\site-packages (from tensorflow-intel==2.16.1->tensorflow) (4.10.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\lenurchik\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\lenurchik\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.62.1)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in c:\users\lenurchik\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in c:\users\lenurchik\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.2.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\lenurchik\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.31.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in c:\users\lenurchik\anaconda3\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\lenurchik\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.16.1->tensorflow) (0.41.2)
# Requirement already satisfied: rich in c:\users\lenurchik\anaconda3\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (13.7.1)
# Requirement already satisfied: namex in c:\users\lenurchik\anaconda3\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.0.7)
# Requirement already satisfied: optree in c:\users\lenurchik\anaconda3\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lenurchik\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenurchik\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lenurchik\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenurchik\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (2024.2.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\lenurchik\anaconda3\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\lenurchik\anaconda3\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\lenurchik\anaconda3\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (3.0.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\lenurchik\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\lenurchik\anaconda3\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\lenurchik\appdata\roaming\python\python311\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (2.17.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\lenurchik\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.1.2)
# Requirement already satisfied: matplotlib in c:\users\lenurchik\anaconda3\lib\site-packages (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lenurchik\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\lenurchik\anaconda3\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lenurchik\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\lenurchik\anaconda3\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.21 in c:\users\lenurchik\anaconda3\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\lenurchik\appdata\roaming\python\python311\site-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=8 in c:\users\lenurchik\anaconda3\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\lenurchik\anaconda3\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lenurchik\appdata\roaming\python\python311\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\lenurchik\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: phik in c:\users\lenurchik\anaconda3\lib\site-packages (0.12.4)
# Requirement already satisfied: numpy>=1.18.0 in c:\users\lenurchik\anaconda3\lib\site-packages (from phik) (1.26.4)
# Requirement already satisfied: scipy>=1.5.2 in c:\users\lenurchik\anaconda3\lib\site-packages (from phik) (1.13.0)
# Requirement already satisfied: pandas>=0.25.1 in c:\users\lenurchik\anaconda3\lib\site-packages (from phik) (2.1.4)
# Requirement already satisfied: matplotlib>=2.2.3 in c:\users\lenurchik\anaconda3\lib\site-packages (from phik) (3.8.4)
# Requirement already satisfied: joblib>=0.14.1 in c:\users\lenurchik\anaconda3\lib\site-packages (from phik) (1.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lenurchik\anaconda3\lib\site-packages (from matplotlib>=2.2.3->phik) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\lenurchik\anaconda3\lib\site-packages (from matplotlib>=2.2.3->phik) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lenurchik\anaconda3\lib\site-packages (from matplotlib>=2.2.3->phik) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\lenurchik\anaconda3\lib\site-packages (from matplotlib>=2.2.3->phik) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\lenurchik\appdata\roaming\python\python311\site-packages (from matplotlib>=2.2.3->phik) (24.0)
# Requirement already satisfied: pillow>=8 in c:\users\lenurchik\anaconda3\lib\site-packages (from matplotlib>=2.2.3->phik) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\lenurchik\anaconda3\lib\site-packages (from matplotlib>=2.2.3->phik) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lenurchik\appdata\roaming\python\python311\site-packages (from matplotlib>=2.2.3->phik) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lenurchik\anaconda3\lib\site-packages (from pandas>=0.25.1->phik) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\lenurchik\anaconda3\lib\site-packages (from pandas>=0.25.1->phik) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\lenurchik\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib>=2.2.3->phik) (1.16.0)
# Requirement already satisfied: scikit-learn in c:\users\lenurchik\anaconda3\lib\site-packages (1.4.2)
# Requirement already satisfied: scipy in c:\users\lenurchik\anaconda3\lib\site-packages (1.13.0)
# Requirement already satisfied: matplotlib in c:\users\lenurchik\anaconda3\lib\site-packages (3.8.4)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\lenurchik\anaconda3\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\lenurchik\anaconda3\lib\site-packages (from scikit-learn) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\lenurchik\anaconda3\lib\site-packages (from scikit-learn) (3.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lenurchik\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\lenurchik\anaconda3\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lenurchik\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\lenurchik\anaconda3\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\lenurchik\appdata\roaming\python\python311\site-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=8 in c:\users\lenurchik\anaconda3\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\lenurchik\anaconda3\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lenurchik\appdata\roaming\python\python311\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\lenurchik\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %% [markdown]
# # Загрузка датасета

# %%
df = pd.read_csv("Downloads/ebw_data.csv", sep=',')

# %% [markdown]
# # Разведочный анализ и визуализация данных

# %%
df.sample(5)
# Out:
#     IW   IF    VW   FP  Depth  Width
# 67  44  146   9.0   60   1.20   1.72
# 64  44  146   9.0   60   1.16   1.76
# 66  44  146   9.0   60   1.24   1.72
# 44  46  146  10.0   60   1.28   1.80
# 25  47  134  10.0  110   0.96   1.94

# %%
#Посмотрим размерность нашего датасета
df.shape
# Out:
# (72, 6)

# %%
#Посмотрим информацию о фрейме данных.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   IW      72 non-null     int64
#  1   IF      72 non-null     int64
#  2   VW      72 non-null     float64
#  3   FP      72 non-null     int64
#  4   Depth   72 non-null     float64
#  5   Width   72 non-null     float64
# dtypes: float64(3), int64(3)
# memory usage: 3.5 KB

# %%
# Проверим набор данные на пропуски
df.isna().sum()
# Out:
# IW       0
# IF       0
# VW       0
# FP       0
# Depth    0
# Width    0
# dtype: int64

# %% [markdown]
# ### Датасет состоит из 72 строк, 6 столбцов, содержит переменные типа float64 и int64. Набор данных качественных характеристик или категориальных признаков не имеет.Пропусков не имеется. Ни одна из записей не является NaN, очистка не требуется.

# %%
#Проверим датасет на дубликаты
df.duplicated().sum()
print('Найдено', len(df) - len(df.drop_duplicates()), 'дубликатов')
# Out:
# Найдено 7 дубликатов

# %%
# Проверим датасет на выбросы.
fig, ax = plt.subplots(figsize=(10, 5))
df.plot(kind='kde', ax=ax);

# %% [markdown]
# ### Строим графики, чтобы наглядно посмотреть на разброс входных данных

# %%
features = list(set(df.columns))
plt.figure(figsize=(10,10))
sns.set_style("whitegrid")
grids = sns.PairGrid(df[features], diag_sharey = False, height = 4)
grids.map_upper(sns.kdeplot)
grids.map_diag(sns.histplot, kde = False)
grids.map_lower(sns.scatterplot)

# %% [markdown]
# Согласно этому графику, мы уже можем сделать вывод, что каждый входной признак по-разному влияет на наши выходные параметры. Увеличение сварочного тока ('IW') приводит к снижению глубины шва ('Depth'), а снижение сварочного тока ('IW') приводит к уменьшению ширины шва ('Width').

# %% [markdown]
# ## Визуализация выбросов с помощью прямоугольного графика

# %%
sns.boxplot(x=df["Depth"])
# Out:
# <Axes: xlabel='Depth'>

# %%
sns.boxplot(x=df["Width"])
# Out:
# <Axes: xlabel='Width'>

# %% [markdown]
# Видим, что наибольшее количество выбросов в столбцах Width и Depth.

# %% [markdown]
# ## Обработка/очистка выброса

# %%
warnings.filterwarnings("ignore")
fig, axes = plt.subplots(1,4)
plt.tight_layout()
## DataFrame
df = pd.read_csv("Downloads/ebw_data.csv", sep=',')
print("Before Shape:",df.shape)
print("Before Shape:",df.shape)
## Max and Min Quantile
max_val = df.Depth.quantile(0.95)
min_val = df.Depth.quantile(0.05)
max_val = df.Width.quantile(0.95)
min_val = df.Width.quantile(0.05)
## Removing all the outliers
df2 = df[(df['Depth']>min_val) & (df['Depth']<max_val)]
df3 = df[(df['Width']>min_val) & (df['Width']<max_val)]
## Visulization
print("After Shape:",df2.shape)
print("After Shape:",df3.shape)
sns.boxplot(df['Depth'],orient='v',ax=axes[0])
axes[0].title.set_text("Before")
sns.boxplot(df['Width'],orient='v',ax=axes[2])
axes[2].title.set_text("Before")
sns.boxplot(df2.shape,orient='v',ax=axes[1])
axes[1].title.set_text("After")
sns.boxplot(df3.shape,orient='v',ax=axes[3])
axes[3].title.set_text("After")
plt.show()
# Out:
# Before Shape: (72, 6)
# Before Shape: (72, 6)
# After Shape: (1, 6)
# After Shape: (59, 6)

# %% [markdown]
# ## Тепловая карта

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#               IW          IF         VW          FP      Depth      Width
# count  72.000000   72.000000  72.000000   72.000000  72.000000  72.000000
# mean   45.666667  141.333333   8.638889   78.333333   1.195556   1.970417
# std     1.678363    5.145763   2.061078   21.493530   0.225081   0.279040
# min    43.000000  131.000000   4.500000   50.000000   0.800000   1.680000
# 25%    44.000000  139.000000   8.000000   60.000000   1.080000   1.760000
# 50%    45.500000  141.000000   9.000000   80.000000   1.200000   1.840000
# 75%    47.000000  146.000000  10.000000   80.000000   1.290000   2.050000
# max    49.000000  150.000000  12.000000  125.000000   1.760000   2.600000

# %%
# Вычисляем коэффициенты ранговой корреляции Кендалла.
df.corr(method = 'kendall')
# Out:
#              IW        IF        VW        FP     Depth     Width
# IW     1.000000 -0.752857  0.135640  0.783660 -0.201166  0.316100
# IF    -0.752857  1.000000  0.072083 -0.912174  0.201041 -0.506440
# VW     0.135640  0.072083  1.000000  0.061463 -0.417191 -0.438444
# FP     0.783660 -0.912174  0.061463  1.000000 -0.339637  0.443478
# Depth -0.201166  0.201041 -0.417191 -0.339637  1.000000 -0.003326
# Width  0.316100 -0.506440 -0.438444  0.443478 -0.003326  1.000000

# %%
korel = df.phik_matrix(interval_cols=[])
plot_correlation_matrix(korel.values, 
                        x_labels = korel.columns, 
                        y_labels = korel.index, 
                        vmin = 0, vmax = 1, color_map = 'GnBu', 
                        title = 'phink', 
                        fontsize_factor = 2, 
                        figsize = (12, 6))
plt.tight_layout(h_pad = 28)

# %% [markdown]
# В некоторых столбцах можем видеть мощную взаимосвязь параметров. Это нам поможет удачно решить поставленную задачу.

# %%
df.plot(x = "FP", y = "IF")
# Корреляция между параметрами равна -0.98, что и видно на этом графике
# Out:
# <Axes: xlabel='FP'>

# %%
df.plot(x = "FP", y = "IW")
# Корреляция положительная и высокая, но график зависимости не донозначный, на мой взгляд
# Out:
# <Axes: xlabel='FP'>

# %%
# На остальных трех графиках мы, кроме хаоса и беспорядка, никакой зависимости зрительной не наблюдаем. Оставлю их здесь для практики и наглядности
df.plot(x = "IW", y = "VW")
df.plot(x = "IF", y = "VW")
df.plot(x = "VW", y = "FP")
# Out:
# <Axes: xlabel='VW'>

# %%
# количество уникальных значений по каждому параметру
df.nunique()
# Не так и много уникальных значений
# Out:
# IW        7
# IF        8
# VW        5
# FP        5
# Depth    29
# Width    25
# dtype: int64

# %% [markdown]
# К сожалению, есть повторяющие строки, но набор данных слишком мал и дальнейшая работа показала, что самое наилучшее предсказание дается на исходном датасете, без внесения каких-либо изменений (удаления дубликатов или добавления данных различными путями(кроме новых достоверных замеров), работы с выбросами или любыми другими манипуляциям данными.

# %% [markdown]
# # Предобработка

# %%
X = df.drop(["Width", "Depth"], axis=1)
Y = df[["Width", "Depth"]].copy()

# %%
X.describe()
# Out:
#               IW          IF         VW          FP
# count  72.000000   72.000000  72.000000   72.000000
# mean   45.666667  141.333333   8.638889   78.333333
# std     1.678363    5.145763   2.061078   21.493530
# min    43.000000  131.000000   4.500000   50.000000
# 25%    44.000000  139.000000   8.000000   60.000000
# 50%    45.500000  141.000000   9.000000   80.000000
# 75%    47.000000  146.000000  10.000000   80.000000
# max    49.000000  150.000000  12.000000  125.000000

# %%
sns.displot(X.IW, kde=True)

# %%
sns.displot(X.IF, kde=True)

# %%
sns.displot(X.VW, kde=True)

# %%
sns.displot(X.FP, kde=True)

# %%
sns.displot(Y.Depth, kde=True)

# %%
sns.displot(Y.Width, kde=True)

# %%
df.isnull().sum()
# Out:
# IW       0
# IF       0
# VW       0
# FP       0
# Depth    0
# Width    0
# dtype: int64

# %% [markdown]
# В итоге никакая дополнительная предобработка данных (кроме нормализации и стандартизации, возможно(?)) нам не треуется больше и можем приступать сразу к нормализации и стандартизации данных, а так же к обучению алгоритмов машинного обучения. Эти пункты я хочу выделить в отдельные разделы, как следующие этапы работы над набором данных.

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, 
                                                    Y, 
                                                    train_size=0.9, 
                                                    test_size=0.1, 
                                                    random_state=0, 
                                                    shuffle=True)

# %%
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
Y = Y.to_numpy()

# %%
X_train.shape, Y_train.shape
# Out:
# ((64, 4), (64, 2))

# %% [markdown]
# # Разработка и обучение нескольких моделей алгоритмов машинного обучения

# %%
model = MultiOutputRegressor(tree.DecisionTreeRegressor())

# %% [markdown]
# # Обучение модели

# %%
model.fit(X_train, Y_train)
# Out:
# MultiOutputRegressor(estimator=DecisionTreeRegressor())

# %% [markdown]
# # Оценка модели

# %%
mean_absolute_error(Y_test, model.predict(X_test), multioutput='raw_values')
# Out:
# array([0.07041667, 0.06551587])

# %%
Y_test.mean(axis=0)
# Out:
# Width    2.0200
# Depth    1.2375
# dtype: float64

# %% [markdown]
# ### В итоге предсказания по ширине и длине сварного шва получились близкими к идеалиным.

# %%
 model = tf.keras.Sequential([
     tf.keras.layers.Dense(units=4, input_dim=4, activation='relu'),
     tf.keras.layers.Dense(units=2, activation='relu')
 ])

# %%
 model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 4)              │            20 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 2)              │            10 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 30 (120.00 B)
#  Trainable params: 30 (120.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
 model.compile(
     optimizer=tf.keras.optimizers.Adam(learning_rate=0.05),
     loss = 'mae',
 )

# %%
# Обучение модели

# %%
model.fit(X_train, Y_train)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.3879

# %%
 history = model.fit(
     x=X_train, 
     y=Y_train,
     validation_data=(X_test, Y_test),
     epochs=50,
     verbose=1
 )
# Out:
# Epoch 1/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - loss: 1.1198 - val_loss: 0.9571
# Epoch 2/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.9343 - val_loss: 0.8373
# Epoch 3/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.7932 - val_loss: 0.6522
# Epoch 4/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.6135 - val_loss: 0.5219
# Epoch 5/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.4727 - val_loss: 0.3979
# Epoch 6/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.3358 - val_loss: 0.2408
# Epoch 7/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.2107 - val_loss: 0.1920
# Epoch 8/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.2236 - val_loss: 0.2376
# Epoch 9/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.2594 - val_loss: 0.2644
# Epoch 10/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.2776 - val_loss: 0.2690
# Epoch 11/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.2716 - val_loss: 0.2292
# Epoch 12/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.2342 - val_loss: 0.1808
# Epoch 13/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1896 - val_loss: 0.1518
# Epoch 14/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1726 - val_loss: 0.1570
# Epoch 15/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1725 - val_loss: 0.1907
# Epoch 16/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1764 - val_loss: 0.2084
# Epoch 17/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1719 - val_loss: 0.1746
# Epoch 18/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1674 - val_loss: 0.1441
# Epoch 19/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1458 - val_loss: 0.1395
# Epoch 20/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.1417 - val_loss: 0.1360
# Epoch 21/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.1434 - val_loss: 0.1308
# Epoch 22/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1408 - val_loss: 0.1356
# Epoch 23/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.1484 - val_loss: 0.1286
# Epoch 24/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1410 - val_loss: 0.1398
# Epoch 25/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1266 - val_loss: 0.1402
# Epoch 26/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1290 - val_loss: 0.1320
# Epoch 27/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1274 - val_loss: 0.1314
# Epoch 28/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1260 - val_loss: 0.1288
# Epoch 29/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1181 - val_loss: 0.1321
# Epoch 30/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1219 - val_loss: 0.1323
# Epoch 31/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1220 - val_loss: 0.1348
# Epoch 32/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1198 - val_loss: 0.1356
# Epoch 33/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1153 - val_loss: 0.1249
# Epoch 34/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1165 - val_loss: 0.1226
# Epoch 35/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1243 - val_loss: 0.1263
# Epoch 36/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1145 - val_loss: 0.1247
# Epoch 37/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1175 - val_loss: 0.1211
# Epoch 38/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.1148 - val_loss: 0.1256
# Epoch 39/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1145 - val_loss: 0.1365
# Epoch 40/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1143 - val_loss: 0.1295
# Epoch 41/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1137 - val_loss: 0.1264
# Epoch 42/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1099 - val_loss: 0.1319
# Epoch 43/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1145 - val_loss: 0.1271
# Epoch 44/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1098 - val_loss: 0.1226
# Epoch 45/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1120 - val_loss: 0.1273
# Epoch 46/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1133 - val_loss: 0.1239
# Epoch 47/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1062 - val_loss: 0.1256
# Epoch 48/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1125 - val_loss: 0.1228
# Epoch 49/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1117 - val_loss: 0.1194
# Epoch 50/50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1144 - val_loss: 0.1259

# %%
 plt.plot(history.history['loss'])
 plt.plot(history.history['val_loss'])
 plt.title('loss')
 plt.ylabel('loss')
 plt.xlabel('epoch')
 plt.legend(['train', 'val'], loc='upper left')
 plt.show()

# %% [markdown]
# ## Оценка модели

# %%
mean_absolute_error(Y_test, model.predict(X_test), multioutput='raw_values')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# array([0.09120111, 0.16063401])

# %%
Y_test.mean(axis=0)
# Out:
# Width    2.0200
# Depth    1.2375
# dtype: float64

# %% [markdown]
# ### В итоге предсказания по ширине и длине сварного шва получились близкими к идеалиным.

# %% [markdown]
# ### Сохранение моделей

# %%
import pickle
saved_model = pickle.dumps('model')

# %%
knn_from_pickle = pickle.loads(saved_model)

# %% [markdown]
# ### Результат работы приложения

# %% [markdown]
# ![%D0%92%D0%B2%D0%BE%D0%B4.JPG](attachment:%D0%92%D0%B2%D0%BE%D0%B4.JPG)

# %% [markdown]
# ![%D0%A0%D0%B5%D0%B7%D1%83%D0%BB%D1%8C%D1%82%D0%B0%D1%82.jpg](attachment:%D0%A0%D0%B5%D0%B7%D1%83%D0%BB%D1%8C%D1%82%D0%B0%D1%82.jpg)
